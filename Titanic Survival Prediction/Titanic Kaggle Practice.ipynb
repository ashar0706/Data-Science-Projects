# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# '/Users/ashar'

# %%
os.chdir('/Users/ashar/Desktop')
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f, ax=plt.subplots(1,4,figsize=(25,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.06],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[2])
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[3])

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_29892ee4_08a6_11e9_90a1_f2189827c158row0_col0 {
#             background-color:  #ffff66;
#         }    #T_29892ee4_08a6_11e9_90a1_f2189827c158row0_col1 {
#             background-color:  #cee666;
#         }    #T_29892ee4_08a6_11e9_90a1_f2189827c158row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_29892ee4_08a6_11e9_90a1_f2189827c158row1_col0 {
#             background-color:  #f6fa66;
#         }    #T_29892ee4_08a6_11e9_90a1_f2189827c158row1_col1 {
#             background-color:  #ffff66;
#         }    #T_29892ee4_08a6_11e9_90a1_f2189827c158row1_col2 {
#             background-color:  #ffff66;
#         }    #T_29892ee4_08a6_11e9_90a1_f2189827c158row2_col0 {
#             background-color:  #60b066;
#         }    #T_29892ee4_08a6_11e9_90a1_f2189827c158row2_col1 {
#             background-color:  #dfef66;
#         }    #T_29892ee4_08a6_11e9_90a1_f2189827c158row2_col2 {
#             background-color:  #90c866;
# ...

# %%
f, ax1 = plt.subplots(1,3,figsize=(18,8))
sns.countplot('Pclass',data = data, ax = ax1[0])
sns.countplot('Pclass', hue = 'Survived', data = data, ax = ax1[1])

# %%
pd.crosstab([data.Pclass,data.Sex],data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row0_col0 {
#             background-color:  #ffff66;
#         }    #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row0_col1 {
#             background-color:  #c5e266;
#         }    #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row0_col2 {
#             background-color:  #fafc66;
#         }    #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row1_col0 {
#             background-color:  #ddee66;
#         }    #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row1_col1 {
#             background-color:  #e9f466;
#         }    #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row1_col2 {
#             background-color:  #f1f866;
#         }    #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row2_col0 {
#             background-color:  #fefe66;
#         }    #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row2_col1 {
#             background-color:  #d6eb66;
#         }    #T_5ddcc4c4_08a8_11e9_90a1_f2189827c158row2_col2 {
#             background-color:  #ffff66;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %%
data['Initial'] = 0
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col0 {
#             background-color:  #ffff66;
#         }    #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col1 {
#             background-color:  #ffff66;
#         }    #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col2 {
#             background-color:  #008066;
#         }    #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col3 {
#             background-color:  #ffff66;
#         }    #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col4 {
#             background-color:  #ffff66;
#         }    #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col5 {
#             background-color:  #ffff66;
#         }    #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col6 {
#             background-color:  #008066;
#         }    #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col7 {
#             background-color:  #ffff66;
#         }    #T_619e3d6a_09a5_11e9_90a1_f2189827c158row0_col8 {
#             background-color:  #ffff66;
# ...

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial
# 0      0         A/5 21171   7.2500   NaN        S      Mr
# 1      0          PC 17599  71.2833   C85        C     Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss
# 3      0            113803  53.1000  C123        S     Mrs
# ...

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial
# 0      0         A/5 21171   7.2500   NaN        S      Mr
# 1      0          PC 17599  71.2833   C85        C     Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss
# 3      0            113803  53.1000  C123        S     Mrs
# ...

# %%
f, ax = plt.subplots(1,2, figsize=(18,8))
data[data['Survived']==0].Age.plot.hist(ax=ax[0], bins = 20, edgecolor='black',color='green')
ax[0].set_title('Survived=0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)        
data[data['Survived']==1].Age.plot.hist(ax=ax[1], bins = 20, edgecolor = 'black', color = 'blue')

# %%
sns.factorplot('Pclass', 'Survived', col='Initial', data=data)
#Shows clear biasedness towards the survival of women!!

# %%
sns.factorplot('Embarked', 'Survived', data=data)

# %%
f, axs = plt.subplots(2,2,figsize=(18,10))
sns.countplot('Embarked', data=data, ax=axs[0,0])
sns.countplot('Embarked', hue='Sex', data=data, ax=axs[1,0])
sns.countplot('Embarked', hue='Survived', data=data, ax=axs[0,1])
sns.countplot('Embarked', hue='Pclass', data=data, ax=axs[1,1])
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0         A/5 21171   7.2500   NaN        S      Mr         1
# 1      0          PC 17599  71.2833   C85        C     Mrs         2
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss         1

# %%
data['Family_Size']=0
data['Family_Size']=data['Parch']+data['SibSp']#family size
data['Alone']=0
data.loc[data.Family_Size==0,'Alone']=1#Alone

# %%
data['Fare_Range']=pd.qcut(data['Fare'], 4)
data['Fare_cat']=0
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)

# %%
sns.heatmap(data.corr(),annot = True, linewidths = 0.7,cmap='RdYlGn', annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(15,12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine

from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix

# %%
data['Embarked'].fillna(0, inplace=True)

# %%
data.isna().sum()
# Out:
# level_0        0
# index          0
# Survived       0
# Pclass         0
# Sex            0
# SibSp          0
# Parch          0
# Embarked       0
# Initial        0
# Age_band       0
# Family_Size    0
# Alone          0
# Fare_cat       0
# dtype: int64

# %%
df1 = data.drop('Survived', axis=1) 
df2 = data['Survived'] 
x_train, x_test, y_train, y_test = train_test_split(df1,df2, test_size=0.3) 
logreg = LogisticRegression() 
logreg.fit(x_train, y_train) 
pred = logreg.predict(x_test) 
print('The Accuracy of Logistic regression is:', metrics.accuracy_score(pred, y_test))
# Out:
# The Accuracy of Logistic regression is: 0.7798507462686567
